# %% [markdown]
# # Spark Moive Recommendation
# In this notebook, we will use an Alternating Least Squares (ALS) algorithm with Spark APIs to predict the ratings for the movies in [MovieLens small dataset](https://grouplens.org/datasets/movielens/latest/)

# %% [markdown]
# ## Report
# ####part0: Data ETL and Data exploration
#
# ####part1: OLAP via Spark SQL
#
# ####part2: Spark ALS for model training
#   grid search, 5-fold validation, best model (rsme: 0.59 on training, 0.88 on test)
#
# ####part3: Recommend movies to user
#   User_based approach, note that the movies that the user has rated will not be recommended.
#
# ####part4: Find similar movies of movie
#   Find k nearest movie factor using LHS.
#   <p>LSH is a randomized algorithm and hashing technique commonly used in large-scale machine learning tasks including clustering and approximate nearest neighbor search.
#   <ref> https://databricks.com/blog/2017/05/09/detecting-abuse-scale-locality-sensitive-hashing-uber-engineering.html

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
import os
os.environ["PYSPARK_PYTHON"] = "python3"
from pyspark.sql import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Part0: Data ETL and Data Exploration

# %%
spark = SparkSession \
    .builder \
    .appName("moive analysis") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movies_df = spark.read.load("/FileStore/tables/movies.csv", format='csv', header = True)
ratings_df = spark.read.load("/FileStore/tables/ratings.csv", format='csv', header = True)
links_df = spark.read.load("/FileStore/tables/links.csv", format='csv', header = True)
tags_df = spark.read.load("/FileStore/tables/tags.csv", format='csv', header = True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movies_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------------+--------------------+
# movieId|               title|              genres|
# +-------+--------------------+--------------------+
#       1|    Toy Story (1995)|Adventure|Animati...|
#       2|      Jumanji (1995)|Adventure|Childre...|
#       3|Grumpier Old Men ...|      Comedy|Romance|
#       4|Waiting to Exhale...|Comedy|Drama|Romance|
#       5|Father of the Bri...|              Comedy|
# +-------+--------------------+--------------------+
# only showing top 5 rows
#
# </div>

# %%
ratings_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+------+---------+
# userId|movieId|rating|timestamp|
# +------+-------+------+---------+
#      1|      1|   4.0|964982703|
#      1|      3|   4.0|964981247|
#      1|      6|   4.0|964982224|
#      1|     47|   5.0|964983815|
#      1|     50|   5.0|964982931|
# +------+-------+------+---------+
# only showing top 5 rows
#
# </div>

# %%
links_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+------+
# movieId| imdbId|tmdbId|
# +-------+-------+------+
#       1|0114709|   862|
#       2|0113497|  8844|
#       3|0113228| 15602|
#       4|0114885| 31357|
#       5|0113041| 11862|
# +-------+-------+------+
# only showing top 5 rows
#
# </div>

# %%
tags_df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+---------------+----------+
# userId|movieId|            tag| timestamp|
# +------+-------+---------------+----------+
#      2|  60756|          funny|1445714994|
#      2|  60756|Highly quotable|1445714996|
#      2|  60756|   will ferrell|1445714992|
#      2|  89774|   Boxing story|1445715207|
#      2|  89774|            MMA|1445715200|
# +------+-------+---------------+----------+
# only showing top 5 rows
#
# </div>

# %%
tmp1 = ratings_df.groupBy("userID").count().toPandas()['count'].min()
tmp2 = ratings_df.groupBy("movieId").count().toPandas()['count'].min()
print('For the users that rated movies and the movies that were rated:')
print('Minimum number of ratings per user is {}'.format(tmp1))
print('Minimum number of ratings per movie is {}'.format(tmp2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">For the users that rated movies and the movies that were rated:
# Minimum number of ratings per user is 20
# Minimum number of ratings per movie is 1
# </div>

# %%
tmp1 = sum(ratings_df.groupBy("movieId").count().toPandas()['count'] == 1)
tmp2 = ratings_df.select('movieId').distinct().count()
print('{} out of {} movies are rated by only one user'.format(tmp1, tmp2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">3446 out of 9724 movies are rated by only one user
# </div>

# %% [markdown]
# ## Part 1: Spark SQL and OLAP

# %%
movies_df.registerTempTable("movies")
ratings_df.registerTempTable("ratings")
links_df.registerTempTable("links")
tags_df.registerTempTable("tags")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select count(*) from ratings
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>100836</td></tr></tbody></table></div>

# %% [markdown]
# ### Q1: The number of Users

# %%
# %sql
select count(distinct userId) as Numer_of_users from ratings
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Numer_of_users</th></tr></thead><tbody><tr><td>610</td></tr></tbody></table></div>

# %% [markdown]
# ### Q2: The number of Movies

# %%
# %sql
select count(distinct movieId) as Numer_of_movies from ratings
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Numer_of_movies</th></tr></thead><tbody><tr><td>9724</td></tr></tbody></table></div>

# %% [markdown]
# ### Q3:  How many movies are rated by users? List movies not rated before

# %%
# %sql
select count(distinct movieId) as Number_movies_are_rated_by_users from ratings
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Number_movies_are_rated_by_users</th></tr></thead><tbody><tr><td>9724</td></tr></tbody></table></div>

# %%
# %sql
select distinct title, genres from movies m
where m.movieId not in (select distinct movieId from ratings)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>title</th><th>genres</th></tr></thead><tbody><tr><td>This Gun for Hire (1942)</td><td>Crime|Film-Noir|Thriller</td></tr><tr><td>Chosen, The (1981)</td><td>Drama</td></tr><tr><td>Innocents, The (1961)</td><td>Drama|Horror|Thriller</td></tr><tr><td>Niagara (1953)</td><td>Drama|Thriller</td></tr><tr><td>Scrooge (1970)</td><td>Drama|Fantasy|Musical</td></tr><tr><td>Browning Version, The (1951)</td><td>Drama</td></tr><tr><td>I Know Where I'm Going! (1945)</td><td>Drama|Romance|War</td></tr><tr><td>For All Mankind (1989)</td><td>Documentary</td></tr><tr><td>Twentieth Century (1934)</td><td>Comedy</td></tr><tr><td>Call Northside 777 (1948)</td><td>Crime|Drama|Film-Noir</td></tr><tr><td>Chalet Girl (2011)</td><td>Comedy|Romance</td></tr><tr><td>Color of Paradise, The (Rang-e khoda) (1999)</td><td>Drama</td></tr><tr><td>Mutiny on the Bounty (1962)</td><td>Adventure|Drama|Romance</td></tr><tr><td>Proof (1991)</td><td>Comedy|Drama|Romance</td></tr><tr><td>In the Realms of the Unreal (2004)</td><td>Animation|Documentary</td></tr><tr><td>Road Home, The (Wo de fu qin mu qin) (1999)</td><td>Drama|Romance</td></tr><tr><td>Roaring Twenties, The (1939)</td><td>Crime|Drama|Thriller</td></tr><tr><td>Parallax View, The (1974)</td><td>Thriller</td></tr></tbody></table></div>

# %% [markdown]
# ### Q4: List Movie Genres

# %%
# %sql
select distinct genres from movies
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>genres</th></tr></thead><tbody><tr><td>Comedy|Horror|Thriller</td></tr><tr><td>Adventure|Sci-Fi|Thriller</td></tr><tr><td>Action|Adventure|Drama|Fantasy</td></tr><tr><td>Action|Drama|Horror</td></tr><tr><td>Action|Animation|Comedy|Sci-Fi</td></tr><tr><td>Animation|Children|Drama|Musical|Romance</td></tr><tr><td>Action|Adventure|Drama</td></tr><tr><td>Adventure|Sci-Fi</td></tr><tr><td>Documentary|Musical|IMAX</td></tr><tr><td>Adventure|Children|Fantasy|Sci-Fi|Thriller</td></tr><tr><td>Adventure|Animation</td></tr><tr><td>Musical|Romance|War</td></tr><tr><td>Action|Adventure|Fantasy|Romance</td></tr><tr><td>Adventure|Children|Drama|Fantasy|IMAX</td></tr><tr><td>Comedy|Crime|Horror|Thriller</td></tr><tr><td>Crime|Drama|Fantasy|Horror|Thriller</td></tr><tr><td>Comedy|Mystery|Thriller</td></tr><tr><td>Adventure|Fantasy</td></tr><tr><td>Horror|Romance|Sci-Fi</td></tr><tr><td>Drama|Film-Noir|Romance</td></tr><tr><td>Crime|Drama|Film-Noir|Mystery|Thriller</td></tr><tr><td>Musical|Western</td></tr><tr><td>Adventure|Animation|Children|Musical|Romance</td></tr><tr><td>Comedy|Crime|Mystery|Romance|Thriller</td></tr><tr><td>Action|Animation|Children|Crime</td></tr><tr><td>Adventure|Horror|Sci-Fi</td></tr><tr><td>Comedy|Drama|Romance|Thriller</td></tr><tr><td>Action|Drama|Mystery|Sci-Fi|Thriller</td></tr><tr><td>Adventure|Animation|Children|Comedy|Drama|Fantasy</td></tr><tr><td>Action|Adventure|Mystery|Sci-Fi</td></tr><tr><td>Adventure|Drama|Romance|Thriller|War</td></tr><tr><td>Animation|Drama</td></tr><tr><td>Horror|Thriller|IMAX</td></tr><tr><td>Crime</td></tr><tr><td>Action|Animation|Film-Noir|Sci-Fi|Thriller</td></tr><tr><td>Action|Crime|Horror|Sci-Fi|Thriller</td></tr><tr><td>Crime|Drama|Thriller</td></tr><tr><td>Action|Adventure|Animation|Sci-Fi</td></tr><tr><td>Action|Adventure|Drama|Fantasy|Mystery|IMAX</td></tr><tr><td>Mystery|Sci-Fi|Thriller</td></tr><tr><td>Adventure|Drama|IMAX</td></tr><tr><td>Romance</td></tr><tr><td>Comedy|Horror|Musical|Sci-Fi</td></tr><tr><td>Children|Drama|Musical</td></tr><tr><td>Action|Drama</td></tr><tr><td>Crime|Thriller</td></tr><tr><td>Drama|Mystery|Sci-Fi|Thriller</td></tr><tr><td>Comedy|Crime|Drama|Western</td></tr><tr><td>Action|Adventure|Drama|Fantasy|Romance|Sci-Fi|Thriller</td></tr><tr><td>Action|Fantasy|Horror|IMAX</td></tr><tr><td>Action|Sci-Fi</td></tr><tr><td>Adventure|Crime|Drama|Romance</td></tr><tr><td>Drama|Fantasy|Mystery|Sci-Fi</td></tr><tr><td>Action|Crime|Mystery</td></tr><tr><td>Animation|Children|Comedy|Fantasy|Musical|Romance|IMAX</td></tr><tr><td>Action|Adventure|Sci-Fi|War|IMAX</td></tr><tr><td>Comedy|Drama|Fantasy|Mystery|Romance</td></tr><tr><td>Children|Comedy|Crime|Drama|Fantasy</td></tr><tr><td>Action|Comedy|Fantasy|IMAX</td></tr><tr><td>Action|Adventure|Fantasy</td></tr><tr><td>Thriller</td></tr><tr><td>Comedy|Fantasy|Romance</td></tr><tr><td>Romance|Thriller</td></tr><tr><td>Adventure|Children|Comedy|Mystery</td></tr><tr><td>Drama|Fantasy|Romance|Sci-Fi</td></tr><tr><td>Documentary|Drama|Thriller</td></tr><tr><td>Crime|Drama|Horror|Mystery|Thriller</td></tr><tr><td>Action|Romance|Thriller</td></tr><tr><td>Action|Crime|Drama|Sci-Fi|Thriller</td></tr><tr><td>Film-Noir|Mystery|Thriller</td></tr><tr><td>Crime|Thriller|War</td></tr><tr><td>Comedy|Drama|Fantasy|Romance</td></tr><tr><td>Adventure|Animation|Children|Comedy|Fantasy|Romance</td></tr><tr><td>Comedy|Crime|Drama|War</td></tr><tr><td>Adventure|Animation|Fantasy|Romance</td></tr><tr><td>Drama|Fantasy|Horror|Romance|Thriller</td></tr><tr><td>Action|Sci-Fi|Thriller|Western|IMAX</td></tr><tr><td>Animation|Children</td></tr><tr><td>Action|Crime|Mystery|Thriller</td></tr><tr><td>Comedy|Romance|Sci-Fi</td></tr><tr><td>Adventure|War|Western</td></tr><tr><td>Action|Animation|Comedy|Fantasy</td></tr><tr><td>Comedy|Horror|Romance</td></tr><tr><td>Comedy|Drama|Musical</td></tr><tr><td>Drama|Film-Noir|Mystery|Roma ...

# %% [markdown]
# This step is tricky. See an example as below.
# <ref>https://sparkbyexamples.com/pyspark/pyspark-explode-nested-array-into-rows/

# %%
# %sql
select title, explode(split(genres,"[|]")) as genres from movies
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>title</th><th>genres</th></tr></thead><tbody><tr><td>Toy Story (1995)</td><td>Adventure</td></tr><tr><td>Toy Story (1995)</td><td>Animation</td></tr><tr><td>Toy Story (1995)</td><td>Children</td></tr><tr><td>Toy Story (1995)</td><td>Comedy</td></tr><tr><td>Toy Story (1995)</td><td>Fantasy</td></tr><tr><td>Jumanji (1995)</td><td>Adventure</td></tr><tr><td>Jumanji (1995)</td><td>Children</td></tr><tr><td>Jumanji (1995)</td><td>Fantasy</td></tr><tr><td>Grumpier Old Men (1995)</td><td>Comedy</td></tr><tr><td>Grumpier Old Men (1995)</td><td>Romance</td></tr><tr><td>Waiting to Exhale (1995)</td><td>Comedy</td></tr><tr><td>Waiting to Exhale (1995)</td><td>Drama</td></tr><tr><td>Waiting to Exhale (1995)</td><td>Romance</td></tr><tr><td>Father of the Bride Part II (1995)</td><td>Comedy</td></tr><tr><td>Heat (1995)</td><td>Action</td></tr><tr><td>Heat (1995)</td><td>Crime</td></tr><tr><td>Heat (1995)</td><td>Thriller</td></tr><tr><td>Sabrina (1995)</td><td>Comedy</td></tr><tr><td>Sabrina (1995)</td><td>Romance</td></tr><tr><td>Tom and Huck (1995)</td><td>Adventure</td></tr><tr><td>Tom and Huck (1995)</td><td>Children</td></tr><tr><td>Sudden Death (1995)</td><td>Action</td></tr><tr><td>GoldenEye (1995)</td><td>Action</td></tr><tr><td>GoldenEye (1995)</td><td>Adventure</td></tr><tr><td>GoldenEye (1995)</td><td>Thriller</td></tr><tr><td>American President, The (1995)</td><td>Comedy</td></tr><tr><td>American President, The (1995)</td><td>Drama</td></tr><tr><td>American President, The (1995)</td><td>Romance</td></tr><tr><td>Dracula: Dead and Loving It (1995)</td><td>Comedy</td></tr><tr><td>Dracula: Dead and Loving It (1995)</td><td>Horror</td></tr><tr><td>Balto (1995)</td><td>Adventure</td></tr><tr><td>Balto (1995)</td><td>Animation</td></tr><tr><td>Balto (1995)</td><td>Children</td></tr><tr><td>Nixon (1995)</td><td>Drama</td></tr><tr><td>Cutthroat Island (1995)</td><td>Action</td></tr><tr><td>Cutthroat Island (1995)</td><td>Adventure</td></tr><tr><td>Cutthroat Island (1995)</td><td>Romance</td></tr><tr><td>Casino (1995)</td><td>Crime</td></tr><tr><td>Casino (1995)</td><td>Drama</td></tr><tr><td>Sense and Sensibility (1995)</td><td>Drama</td></tr><tr><td>Sense and Sensibility (1995)</td><td>Romance</td></tr><tr><td>Four Rooms (1995)</td><td>Comedy</td></tr><tr><td>Ace Ventura: When Nature Calls (1995)</td><td>Comedy</td></tr><tr><td>Money Train (1995)</td><td>Action</td></tr><tr><td>Money Train (1995)</td><td>Comedy</td></tr><tr><td>Money Train (1995)</td><td>Crime</td></tr><tr><td>Money Train (1995)</td><td>Drama</td></tr><tr><td>Money Train (1995)</td><td>Thriller</td></tr><tr><td>Get Shorty (1995)</td><td>Comedy</td></tr><tr><td>Get Shorty (1995)</td><td>Crime</td></tr><tr><td>Get Shorty (1995)</td><td>Thriller</td></tr><tr><td>Copycat (1995)</td><td>Crime</td></tr><tr><td>Copycat (1995)</td><td>Drama</td></tr><tr><td>Copycat (1995)</td><td>Horror</td></tr><tr><td>Copycat (1995)</td><td>Mystery</td></tr><tr><td>Copycat (1995)</td><td>Thriller</td></tr><tr><td>Assassins (1995)</td><td>Action</td></tr><tr><td>Assassins (1995)</td><td>Crime</td></tr><tr><td>Assassins (1995)</td><td>Thriller</td></tr><tr><td>Powder (1995)</td><td>Drama</td></tr><tr><td>Powder (1995)</td><td>Sci-Fi</td></tr><tr><td>Leaving Las Vegas (1995)</td><td>Drama</td></tr><tr><td>Leaving Las Vegas (1995)</td><td>Romance</td></tr><tr><td>Othello (1995)</td><td>Drama</td></tr><tr><td>Now and Then (1995)</td><td>Children</td></tr><tr><td>Now and Then (1995)</td><td>Drama</td></tr><tr><td>Persuasion (1995)</td><td>Drama</td></tr><tr><td>Persuasion (1995)</td><td>Romance</td></tr><tr><td>City of Lost Children, The (Cité des enfants perdus, La) (1995)</td><td>Adventure</td></tr><tr><td>City of Lost Children, The (Cité des enfants perdus, La) (1995)</td><td>Drama</td></tr><tr><td>City of Lost Children, The (Cité des enfants perdus, La) (1995)</td><td>Fantasy</ ...

# %%
# %sql
select distinct explode(split(genres,"[|]")) as genres from movies
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>genres</th></tr></thead><tbody><tr><td>Crime</td></tr><tr><td>Romance</td></tr><tr><td>Thriller</td></tr><tr><td>Adventure</td></tr><tr><td>Drama</td></tr><tr><td>War</td></tr><tr><td>Documentary</td></tr><tr><td>Fantasy</td></tr><tr><td>Mystery</td></tr><tr><td>Musical</td></tr><tr><td>Animation</td></tr><tr><td>Film-Noir</td></tr><tr><td>(no genres listed)</td></tr><tr><td>IMAX</td></tr><tr><td>Horror</td></tr><tr><td>Western</td></tr><tr><td>Comedy</td></tr><tr><td>Children</td></tr><tr><td>Action</td></tr><tr><td>Sci-Fi</td></tr></tbody></table></div>

# %% [markdown]
# ### Q5: Movie for Each Category

# %%
# %sql
select genres as category, count(distinct title) as count
from (select title, explode(split(genres,"[|]")) as genres from movies)
group by 1
order by 2 desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>count</th></tr></thead><tbody><tr><td>Drama</td><td>4359</td></tr><tr><td>Comedy</td><td>3755</td></tr><tr><td>Thriller</td><td>1892</td></tr><tr><td>Action</td><td>1827</td></tr><tr><td>Romance</td><td>1595</td></tr><tr><td>Adventure</td><td>1263</td></tr><tr><td>Crime</td><td>1198</td></tr><tr><td>Sci-Fi</td><td>978</td></tr><tr><td>Horror</td><td>978</td></tr><tr><td>Fantasy</td><td>779</td></tr><tr><td>Children</td><td>664</td></tr><tr><td>Animation</td><td>611</td></tr><tr><td>Mystery</td><td>573</td></tr><tr><td>Documentary</td><td>440</td></tr><tr><td>War</td><td>382</td></tr><tr><td>Musical</td><td>334</td></tr><tr><td>Western</td><td>167</td></tr><tr><td>IMAX</td><td>158</td></tr><tr><td>Film-Noir</td><td>87</td></tr><tr><td>(no genres listed)</td><td>34</td></tr></tbody></table></div>

# %% [markdown]
# ## Part2: Spark ALS based approach for training model
# We will use an Spark ML to predict the ratings, so let's reload "ratings.csv" using ``sc.textFile`` and then convert it to the form of (user, item, rating) tuples.

# %%
ratings_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+------+---------+
# userId|movieId|rating|timestamp|
# +------+-------+------+---------+
#      1|      1|   4.0|964982703|
#      1|      3|   4.0|964981247|
#      1|      6|   4.0|964982224|
#      1|     47|   5.0|964983815|
#      1|     50|   5.0|964982931|
#      1|     70|   3.0|964982400|
#      1|    101|   5.0|964980868|
#      1|    110|   4.0|964982176|
#      1|    151|   5.0|964984041|
#      1|    157|   5.0|964984100|
#      1|    163|   5.0|964983650|
#      1|    216|   5.0|964981208|
#      1|    223|   3.0|964980985|
#      1|    231|   5.0|964981179|
#      1|    235|   4.0|964980908|
#      1|    260|   5.0|964981680|
#      1|    296|   3.0|964982967|
#      1|    316|   3.0|964982310|
#      1|    333|   5.0|964981179|
#      1|    349|   4.0|964982563|
# +------+-------+------+---------+
# only showing top 20 rows
#
# </div>

# %%
movie_ratings=ratings_df.drop('timestamp')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Data type convert
from pyspark.sql.types import IntegerType, FloatType
movie_ratings = movie_ratings.withColumn("userId", movie_ratings["userId"].cast(IntegerType()))
movie_ratings = movie_ratings.withColumn("movieId", movie_ratings["movieId"].cast(IntegerType()))
movie_ratings = movie_ratings.withColumn("rating", movie_ratings["rating"].cast(FloatType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
movie_ratings.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+------+
# userId|movieId|rating|
# +------+-------+------+
#      1|      1|   4.0|
#      1|      3|   4.0|
#      1|      6|   4.0|
#      1|     47|   5.0|
#      1|     50|   5.0|
#      1|     70|   3.0|
#      1|    101|   5.0|
#      1|    110|   4.0|
#      1|    151|   5.0|
#      1|    157|   5.0|
#      1|    163|   5.0|
#      1|    216|   5.0|
#      1|    223|   3.0|
#      1|    231|   5.0|
#      1|    235|   4.0|
#      1|    260|   5.0|
#      1|    296|   3.0|
#      1|    316|   3.0|
#      1|    333|   5.0|
#      1|    349|   4.0|
# +------+-------+------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### ALS Model Selection and Evaluation
#
# With the ALS model, we can use a grid search to find the optimal hyperparameters.
# <ref>https://spark.apache.org/docs/2.2.0/api/python/pyspark.ml.html#pyspark.ml.recommendation.ALS

# %%
# import package
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Create test and train set
(training,test)=movie_ratings.randomSplit([0.8,0.2])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Create ALS model
als = ALS(maxIter=5, rank=10, regParam=0.01, userCol="userId", itemCol="movieId", ratingCol="rating",
          coldStartStrategy="drop")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(als.explainParams())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">alpha: alpha for implicit preference (default: 1.0)
# checkpointInterval: set checkpoint interval (&gt;= 1) or disable checkpoint (-1). E.g. 10 means that the cache will get checkpointed every 10 iterations. Note: this setting will be ignored if the checkpoint directory is not set in the SparkContext. (default: 10)
# coldStartStrategy: strategy for dealing with unknown or new users/items at prediction time. This may be useful in cross-validation or production scenarios, for handling user/item ids the model has not seen in the training data. Supported values: &#39;nan&#39;, &#39;drop&#39;. (default: nan, current: drop)
# finalStorageLevel: StorageLevel for ALS model factors. (default: MEMORY_AND_DISK)
# implicitPrefs: whether to use implicit preference (default: False)
# intermediateStorageLevel: StorageLevel for intermediate datasets. Cannot be &#39;NONE&#39;. (default: MEMORY_AND_DISK)
# itemCol: column name for item ids. Ids must be within the integer value range. (default: item, current: movieId)
# maxIter: max number of iterations (&gt;= 0). (default: 10, current: 5)
# nonnegative: whether to use nonnegative constraint for least squares (default: False)
# numItemBlocks: number of item blocks (default: 10)
# numUserBlocks: number of user blocks (default: 10)
# predictionCol: prediction column name. (default: prediction)
# rank: rank of the factorization (default: 10, current: 10)
# ratingCol: column name for ratings (default: rating, current: rating)
# regParam: regularization parameter (&gt;= 0). (default: 0.1, current: 0.01)
# seed: random seed. (default: -1517157561977538513)
# userCol: column name for user ids. Ids must be within the integer value range. (default: user, current: userId)
# </div>

# %%
#Tune model using ParamGridBuilder
paramGrid = (ParamGridBuilder()
             .addGrid(als.maxIter, [5, 10, 15])
             .addGrid(als.rank, [10, 15, 20])
             .addGrid(als.regParam, [0.01, 0.1, 0.5])
             .build())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Define evaluator as RMSE
evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating",
                                predictionCol="prediction")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Build Cross validation 
cv = CrossValidator(estimator=als, estimatorParamMaps=paramGrid, evaluator=evaluator, numFolds=5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Fit ALS model to training data
cvModel = cv.fit(training)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/ml/util.py:791: UserWarning: Can not find mlflow. To enable mlflow logging, install MLflow library from PyPi.
#   warnings.warn(_MLflowInstrumentation._NO_MLFLOW_WARNING)
# </div>

# %%
#Extract best model from the tuning exercise using ParamGridBuilder
best_model = cvModel.bestModel
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Model testing
# And finally, make a prediction and check the testing error.

# %%
#Generate predictions and evaluate using RMSE
predictions = best_model.transform(test)
rmse = evaluator.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Print evaluation metrics and model parameters
print ("RMSE = "+str(rmse))
print ("**Best Model**")
print (" Rank:", best_model.rank)
print (" MaxIter:", best_model._java_obj.parent().getMaxIter())
print (" RegParam:", best_model._java_obj.parent().getRegParam())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE = 0.8845023869138565
# **Best Model**
#  Rank: 20
#  MaxIter: 15
#  RegParam: 0.1
# </div>

# %%
predictions.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------+------+----------+
# userId|movieId|rating|prediction|
# +------+-------+------+----------+
#    436|    471|   3.0| 3.7310843|
#    217|    471|   2.0| 2.7553773|
#    287|    471|   4.5| 2.8674417|
#    373|    471|   5.0| 3.0631754|
#    606|   1088|   3.0| 3.1204278|
#    177|   1088|   3.5| 3.6185944|
#    489|   1088|   4.5|  2.829762|
#    286|   1088|   3.5| 3.0165346|
#     84|   1088|   3.0| 3.2697804|
#     51|   1088|   4.0|  2.938944|
#    221|   1088|   3.0| 3.0399182|
#    116|   1088|   4.5| 3.0709426|
#     42|   1088|   3.0| 3.2740774|
#    469|   1238|   5.0| 3.8678803|
#    137|   1580|   3.5|  3.401046|
#    606|   1580|   2.5| 3.1561527|
#    367|   1580|   4.0| 3.7170281|
#     47|   1580|   1.5| 2.6396267|
#    603|   1580|   4.0| 2.8209295|
#    283|   1580|   4.0| 2.9443934|
# +------+-------+------+----------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### Model apply and see the performance

# %%
alldata=best_model.transform(movie_ratings)
rmse = evaluator.evaluate(alldata)
print ("RMSE = "+str(rmse))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE = 0.5909738459865683
# </div>

# %%
alldata.registerTempTable("alldata")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql select * from alldata
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>movieId</th><th>rating</th><th>prediction</th></tr></thead><tbody><tr><td>191</td><td>148</td><td>5.0</td><td>4.9203944</td></tr><tr><td>133</td><td>471</td><td>4.0</td><td>3.341171</td></tr><tr><td>597</td><td>471</td><td>2.0</td><td>3.4518747</td></tr><tr><td>385</td><td>471</td><td>4.0</td><td>3.383218</td></tr><tr><td>436</td><td>471</td><td>3.0</td><td>3.7310843</td></tr><tr><td>602</td><td>471</td><td>4.0</td><td>3.5697618</td></tr><tr><td>91</td><td>471</td><td>1.0</td><td>2.4314399</td></tr><tr><td>409</td><td>471</td><td>3.0</td><td>3.5237584</td></tr><tr><td>372</td><td>471</td><td>3.0</td><td>3.0369964</td></tr><tr><td>599</td><td>471</td><td>2.5</td><td>2.745125</td></tr><tr><td>603</td><td>471</td><td>4.0</td><td>3.0849226</td></tr><tr><td>182</td><td>471</td><td>4.5</td><td>3.9771624</td></tr><tr><td>218</td><td>471</td><td>4.0</td><td>3.8772278</td></tr><tr><td>474</td><td>471</td><td>3.0</td><td>3.2731175</td></tr><tr><td>500</td><td>471</td><td>1.0</td><td>2.0989964</td></tr><tr><td>57</td><td>471</td><td>3.0</td><td>3.4126818</td></tr><tr><td>462</td><td>471</td><td>2.5</td><td>2.2548358</td></tr><tr><td>387</td><td>471</td><td>3.0</td><td>2.6138434</td></tr><tr><td>610</td><td>471</td><td>4.0</td><td>3.4051142</td></tr><tr><td>217</td><td>471</td><td>2.0</td><td>2.7553773</td></tr><tr><td>555</td><td>471</td><td>3.0</td><td>3.1501887</td></tr><tr><td>176</td><td>471</td><td>5.0</td><td>4.4736857</td></tr><tr><td>520</td><td>471</td><td>5.0</td><td>4.2510476</td></tr><tr><td>136</td><td>471</td><td>4.0</td><td>3.8436751</td></tr><tr><td>171</td><td>471</td><td>3.0</td><td>3.7188578</td></tr><tr><td>273</td><td>471</td><td>5.0</td><td>4.777414</td></tr><tr><td>448</td><td>471</td><td>4.0</td><td>3.499086</td></tr><tr><td>312</td><td>471</td><td>4.0</td><td>3.5011144</td></tr><tr><td>216</td><td>471</td><td>3.0</td><td>2.824453</td></tr><tr><td>411</td><td>471</td><td>4.0</td><td>3.386854</td></tr><tr><td>287</td><td>471</td><td>4.5</td><td>2.8674417</td></tr><tr><td>32</td><td>471</td><td>3.0</td><td>3.385501</td></tr><tr><td>469</td><td>471</td><td>5.0</td><td>3.843469</td></tr><tr><td>414</td><td>471</td><td>5.0</td><td>3.867844</td></tr><tr><td>608</td><td>471</td><td>1.5</td><td>2.2386806</td></tr><tr><td>426</td><td>471</td><td>5.0</td><td>4.299166</td></tr><tr><td>541</td><td>471</td><td>3.0</td><td>3.2872586</td></tr><tr><td>260</td><td>471</td><td>4.5</td><td>3.9172876</td></tr><tr><td>373</td><td>471</td><td>5.0</td><td>3.0631754</td></tr><tr><td>357</td><td>471</td><td>3.5</td><td>3.8348148</td></tr><tr><td>104</td><td>471</td><td>4.5</td><td>4.0709257</td></tr><tr><td>191</td><td>496</td><td>5.0</td><td>4.9203944</td></tr><tr><td>44</td><td>833</td><td>2.0</td><td>2.147658</td></tr><tr><td>599</td><td>833</td><td>1.5</td><td>1.4217784</td></tr><tr><td>609</td><td>833</td><td>3.0</td><td>2.463377</td></tr><tr><td>307</td><td>833</td><td>1.0</td><td>1.0780809</td></tr><tr><td>492</td><td>833</td><td>4.0</td><td>3.6831694</td></tr><tr><td>608</td><td>833</td><td>0.5</td><td>0.88879573</td></tr><tr><td>463</td><td>1088</td><td>3.5</td><td>3.2170722</td></tr><tr><td>159</td><td>1088</td><td>4.0</td><td>3.6158848</td></tr><tr><td>606</td><td>1088</td><td>3.0</td><td>3.1204278</td></tr><tr><td>599</td><td>1088</td><td>2.5</td><td>2.384417</td></tr><tr><td>111</td><td>1088</td><td>3.0</td><td>3.2231207</td></tr><tr><td>47</td><td>1088</td><td>4.0</td><td>3.1965466</td></tr><tr><td>177</td><td>1088</td><td>3.5</td><td>3.6185944</td></tr><tr><td>132</td><td>1088</td><td>4.0</td><td>3.0808198</td></tr><tr><td>474</td><td>1088</td><td>3.5</td><td>3.0151036</td></tr><tr><td>20</td><td>1088</td><td>4.5</td><td>3.6610823</td></tr><tr><td>169</td><td>1088</td><td>4.5</td><td>4.382472</td></tr><tr><td>479</td><td>1088</td><td>4.0</td><td>3.4469013</td></tr><tr><td>64</td><td>1088</td> ...

# %%
# %sql select * from movies join alldata on movies.movieId=alldata.movieId
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th><th>genres</th><th>userId</th><th>movieId</th><th>rating</th><th>prediction</th></tr></thead><tbody><tr><td>148</td><td>Awfully Big Adventure, An (1995)</td><td>Drama</td><td>191</td><td>148</td><td>5.0</td><td>4.9203944</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>133</td><td>471</td><td>4.0</td><td>3.341171</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>597</td><td>471</td><td>2.0</td><td>3.4518747</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>385</td><td>471</td><td>4.0</td><td>3.383218</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>436</td><td>471</td><td>3.0</td><td>3.7310843</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>602</td><td>471</td><td>4.0</td><td>3.5697618</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>91</td><td>471</td><td>1.0</td><td>2.4314399</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>409</td><td>471</td><td>3.0</td><td>3.5237584</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>372</td><td>471</td><td>3.0</td><td>3.0369964</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>599</td><td>471</td><td>2.5</td><td>2.745125</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>603</td><td>471</td><td>4.0</td><td>3.0849226</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>182</td><td>471</td><td>4.5</td><td>3.9771624</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>218</td><td>471</td><td>4.0</td><td>3.8772278</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>474</td><td>471</td><td>3.0</td><td>3.2731175</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>500</td><td>471</td><td>1.0</td><td>2.0989964</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>57</td><td>471</td><td>3.0</td><td>3.4126818</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>462</td><td>471</td><td>2.5</td><td>2.2548358</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>387</td><td>471</td><td>3.0</td><td>2.6138434</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>610</td><td>471</td><td>4.0</td><td>3.4051142</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>217</td><td>471</td><td>2.0</td><td>2.7553773</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>555</td><td>471</td><td>3.0</td><td>3.1501887</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>176</td><td>471</td><td>5.0</td><td>4.4736857</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>520</td><td>471</td><td>5.0</td><td>4.2510476</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>136</td><td>471</td><td>4.0</td><td>3.8436751</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>171</td><td>471</td><td>3.0</td><td>3.7188578</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>273</td><td>471</td><td>5.0</td><td>4.777414</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>448</td><td>471</td><td>4.0</td><td>3.499086</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>312</td><td>471</td><td>4.0</td><td>3.5011144</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>216</td><td>471</td><td>3.0</td><td>2.824453</td></tr><tr><td>471</td><td>Hudsucker Proxy, The (1994)</td><td>Comedy</td><td>411</td><td>471</td><td>4.0</td><t ...

# %% [markdown]
# ## Part3: Recommend moives to users
# you can choose some users to recommend the moives

# %%
# recommend 5 movies for each users 
als_user_recs = best_model.recommendForAllUsers(5)
user_recs.registerTempTable("als_user_recs")
display(als_user_recs)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>recommendations</th></tr></thead><tbody><tr><td>471</td><td>List(List(177593, 4.5729346), List(170705, 4.432933), List(170355, 4.3702784), List(55363, 4.3607764), List(3201, 4.328181))</td></tr><tr><td>463</td><td>List(List(177593, 5.0999756), List(80906, 4.8039575), List(69524, 4.789617), List(3200, 4.7765493), List(170355, 4.7352614))</td></tr><tr><td>496</td><td>List(List(7099, 4.85922), List(177593, 4.771958), List(51931, 4.5685368), List(101, 4.549831), List(5618, 4.498313))</td></tr><tr><td>148</td><td>List(List(160718, 4.3862305), List(177593, 4.31868), List(122918, 4.2864337), List(183897, 4.2264643), List(40629, 4.1998296))</td></tr><tr><td>540</td><td>List(List(177593, 5.659834), List(3200, 4.9527864), List(78836, 4.927608), List(123, 4.8638678), List(318, 4.8332086))</td></tr><tr><td>392</td><td>List(List(6380, 4.9689326), List(750, 4.886894), List(103984, 4.8670797), List(2599, 4.7894044), List(26131, 4.767499))</td></tr><tr><td>243</td><td>List(List(177593, 5.3528185), List(84273, 5.325616), List(26073, 5.325616), List(7071, 5.325616), List(117531, 5.325616))</td></tr><tr><td>31</td><td>List(List(932, 5.503551), List(177593, 5.1505103), List(899, 4.9961877), List(674, 4.89535), List(1939, 4.8482013))</td></tr><tr><td>516</td><td>List(List(177593, 4.978042), List(1250, 4.8788342), List(4429, 4.862645), List(1262, 4.8074036), List(3200, 4.7696185))</td></tr><tr><td>580</td><td>List(List(177593, 4.8197393), List(53123, 4.746355), List(71462, 4.633043), List(80906, 4.574043), List(84847, 4.5648212))</td></tr><tr><td>251</td><td>List(List(177593, 5.781053), List(3201, 5.2078905), List(1204, 5.1487007), List(318, 5.1233215), List(306, 5.1129208))</td></tr><tr><td>451</td><td>List(List(177593, 5.629806), List(4973, 5.077737), List(898, 5.070145), List(7096, 5.0278525), List(905, 4.978465))</td></tr><tr><td>85</td><td>List(List(1250, 5.0749936), List(1262, 5.0250235), List(177593, 4.96943), List(1203, 4.9518085), List(912, 4.929535))</td></tr><tr><td>137</td><td>List(List(177593, 4.7603164), List(750, 4.7257133), List(6650, 4.692726), List(1949, 4.665702), List(246, 4.640373))</td></tr><tr><td>65</td><td>List(List(177593, 5.27734), List(78836, 4.5919466), List(183897, 4.585012), List(170705, 4.5704803), List(6442, 4.5518365))</td></tr><tr><td>458</td><td>List(List(177593, 5.3669477), List(5466, 5.2854753), List(92259, 5.0978484), List(3200, 5.0723195), List(86781, 5.0478015))</td></tr><tr><td>481</td><td>List(List(177593, 4.493226), List(2398, 4.396707), List(955, 4.2917914), List(899, 4.211444), List(1957, 4.2016807))</td></tr><tr><td>53</td><td>List(List(177593, 7.283532), List(78836, 6.640131), List(117531, 6.4524965), List(7071, 6.4524965), List(84273, 6.4524965))</td></tr><tr><td>255</td><td>List(List(3525, 4.985321), List(1194, 4.639338), List(3421, 4.2680454), List(3552, 4.2368884), List(2411, 4.094741))</td></tr><tr><td>588</td><td>List(List(177593, 4.636242), List(86345, 4.2733555), List(296, 4.2710786), List(170355, 4.26856), List(92535, 4.23032))</td></tr><tr><td>472</td><td>List(List(177593, 5.401354), List(3836, 5.3518357), List(51931, 5.2648597), List(932, 5.072727), List(27611, 5.024961))</td></tr><tr><td>133</td><td>List(List(720, 3.90818), List(177593, 3.706783), List(1262, 3.613129), List(1148, 3.606249), List(3200, 3.6040442))</td></tr><tr><td>296</td><td>List(List(177593, 5.5204935), List(1203, 5.2018285), List(899, 5.17683), List(3949, 5.108031), List(1178, 5.048267))</td></tr><tr><td>322</td><td>List(List(177593, 4.4975104), List(5490, 4.2677794), List(105504, 4.2305403), List(183897, 4.136564), List(3494, 4.124968))</td></tr><tr><td>513</td><td>List(List(1262, 4.9536033), List(1250, 4.7983694), List(177593, 4.744732), List(3200, 4.6869063), List(260, 4.6818686))</td></tr><tr><td>78</td><td>List(List(5466, 4.2970448), List(3836, 4.2562327), List(1232, 4.2514763), List( ...

# %%
final_rec = spark.sql("SELECT userId, rec.movieId AS movieId, rec.rating AS prediction \
                       FROM (select userId, explode(recommendations) AS rec FROM als_user_recs)")
final_rec = final_rec.join(movie_ratings,['userId','movieId'],'left').filter(movie_ratings.rating.isNull())
display(final_rec)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>movieId</th><th>prediction</th><th>rating</th></tr></thead><tbody><tr><td>471</td><td>177593</td><td>4.5729346</td><td>null</td></tr><tr><td>471</td><td>170705</td><td>4.432933</td><td>null</td></tr><tr><td>471</td><td>170355</td><td>4.3702784</td><td>null</td></tr><tr><td>471</td><td>55363</td><td>4.3607764</td><td>null</td></tr><tr><td>471</td><td>3201</td><td>4.328181</td><td>null</td></tr><tr><td>463</td><td>177593</td><td>5.0999756</td><td>null</td></tr><tr><td>463</td><td>80906</td><td>4.8039575</td><td>null</td></tr><tr><td>463</td><td>69524</td><td>4.789617</td><td>null</td></tr><tr><td>463</td><td>3200</td><td>4.7765493</td><td>null</td></tr><tr><td>463</td><td>170355</td><td>4.7352614</td><td>null</td></tr><tr><td>496</td><td>7099</td><td>4.85922</td><td>null</td></tr><tr><td>496</td><td>177593</td><td>4.771958</td><td>null</td></tr><tr><td>496</td><td>51931</td><td>4.5685368</td><td>null</td></tr><tr><td>496</td><td>101</td><td>4.549831</td><td>null</td></tr><tr><td>496</td><td>5618</td><td>4.498313</td><td>null</td></tr><tr><td>148</td><td>177593</td><td>4.31868</td><td>null</td></tr><tr><td>148</td><td>122918</td><td>4.2864337</td><td>null</td></tr><tr><td>148</td><td>183897</td><td>4.2264643</td><td>null</td></tr><tr><td>540</td><td>177593</td><td>5.659834</td><td>null</td></tr><tr><td>540</td><td>3200</td><td>4.9527864</td><td>null</td></tr><tr><td>540</td><td>78836</td><td>4.927608</td><td>null</td></tr><tr><td>540</td><td>123</td><td>4.8638678</td><td>null</td></tr><tr><td>540</td><td>318</td><td>4.8332086</td><td>null</td></tr><tr><td>392</td><td>6380</td><td>4.9689326</td><td>null</td></tr><tr><td>392</td><td>750</td><td>4.886894</td><td>null</td></tr><tr><td>392</td><td>103984</td><td>4.8670797</td><td>null</td></tr><tr><td>392</td><td>2599</td><td>4.7894044</td><td>null</td></tr><tr><td>392</td><td>26131</td><td>4.767499</td><td>null</td></tr><tr><td>243</td><td>177593</td><td>5.3528185</td><td>null</td></tr><tr><td>243</td><td>84273</td><td>5.325616</td><td>null</td></tr><tr><td>243</td><td>26073</td><td>5.325616</td><td>null</td></tr><tr><td>243</td><td>7071</td><td>5.325616</td><td>null</td></tr><tr><td>243</td><td>117531</td><td>5.325616</td><td>null</td></tr><tr><td>31</td><td>932</td><td>5.503551</td><td>null</td></tr><tr><td>31</td><td>177593</td><td>5.1505103</td><td>null</td></tr><tr><td>31</td><td>899</td><td>4.9961877</td><td>null</td></tr><tr><td>31</td><td>674</td><td>4.89535</td><td>null</td></tr><tr><td>31</td><td>1939</td><td>4.8482013</td><td>null</td></tr><tr><td>516</td><td>177593</td><td>4.978042</td><td>null</td></tr><tr><td>516</td><td>1250</td><td>4.8788342</td><td>null</td></tr><tr><td>516</td><td>1262</td><td>4.8074036</td><td>null</td></tr><tr><td>516</td><td>3200</td><td>4.7696185</td><td>null</td></tr><tr><td>580</td><td>177593</td><td>4.8197393</td><td>null</td></tr><tr><td>580</td><td>53123</td><td>4.746355</td><td>null</td></tr><tr><td>580</td><td>71462</td><td>4.633043</td><td>null</td></tr><tr><td>580</td><td>80906</td><td>4.574043</td><td>null</td></tr><tr><td>580</td><td>84847</td><td>4.5648212</td><td>null</td></tr><tr><td>251</td><td>177593</td><td>5.781053</td><td>null</td></tr><tr><td>251</td><td>3201</td><td>5.2078905</td><td>null</td></tr><tr><td>251</td><td>1204</td><td>5.1487007</td><td>null</td></tr><tr><td>251</td><td>306</td><td>5.1129208</td><td>null</td></tr><tr><td>451</td><td>177593</td><td>5.629806</td><td>null</td></tr><tr><td>451</td><td>4973</td><td>5.077737</td><td>null</td></tr><tr><td>451</td><td>898</td><td>5.070145</td><td>null</td></tr><tr><td>451</td><td>7096</td><td>5.0278525</td><td>null</td></tr><tr><td>451</td><td>905</td><td>4.978465</td><td>null</td></tr><tr><td>85</td><td>1250</td><td>5.0749936</td><td>null</td></tr><tr><td>85</td><td>1262</td><td>5.0250235</td><td>null</td></tr><tr><td>85</td><td>177593</td ...

# %%
final_rec.registerTempTable("final_rec")
movies_df = movies_df.withColumn("movieId", movies_df["movieId"].cast(IntegerType()))
movies_df.registerTempTable("movies_df")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Recommend moive to user with id: 575

# %%
# %sql
select movieId, title from movies_df
where movieId in (select movieId from final_rec where userId = 575)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th></tr></thead><tbody><tr><td>116897</td><td>Wild Tales (2014)</td></tr><tr><td>177593</td><td>Three Billboards Outside Ebbing, Missouri (2017)</td></tr><tr><td>123</td><td>Chungking Express (Chung Hing sam lam) (1994)</td></tr><tr><td>51931</td><td>Reign Over Me (2007)</td></tr></tbody></table></div>

# %% [markdown]
# ### Recommend moive to user with id: 232

# %%
# %sql
select movieId, title from movies_df
where movieId in (select movieId from final_rec where userId = 232)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th></tr></thead><tbody><tr><td>170705</td><td>Band of Brothers (2001)</td></tr><tr><td>92259</td><td>Intouchables (2011)</td></tr><tr><td>177593</td><td>Three Billboards Outside Ebbing, Missouri (2017)</td></tr><tr><td>142020</td><td>Oscar (1967)</td></tr><tr><td>78836</td><td>Enter the Void (2009)</td></tr></tbody></table></div>

# %% [markdown]
# ## Part4: Find the similar moives for moive
# You can find the similar moives based on the ALS results
# <ref>https://databricks.com/blog/2017/05/09/detecting-abuse-scale-locality-sensitive-hashing-uber-engineering.html
# <ref>https://spark.apache.org/docs/2.2.0/api/python/pyspark.ml.html#pyspark.ml.feature.BucketedRandomProjectionLSH

# %%
from pyspark.ml.feature import BucketedRandomProjectionLSH
from pyspark.ml.linalg import Vectors, VectorUDT
from pyspark.sql.functions import col
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
item_factors = best_model.itemFactors
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
to_vector = udf(lambda x: Vectors.dense(x), VectorUDT())
item_factors = item_factors.select("id", to_vector("features").alias("features"))
item_factors.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+--------------------+
#  id|            features|
# +---+--------------------+
#  10|[0.11144769191741...|
#  20|[0.43100905418395...|
#  30|[0.06017402932047...|
#  40|[0.53567087650299...|
#  50|[0.28189906477928...|
# +---+--------------------+
# only showing top 5 rows
#
# </div>

# %%
brp = BucketedRandomProjectionLSH(inputCol="features", outputCol="hashes", seed=12345, bucketLength=1.0)
model_brp = brp.fit(item_factors)
item_factors = model_brp.transform(item_factors)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
item_similarities = model_brp.approxSimilarityJoin(item_factors, item_factors, 3.0, distCol="EuclideanDistance").select(
...     col("datasetA.id").alias("idA"),
...     col("datasetB.id").alias("idB"),
...     col("EuclideanDistance"))
item_similarities = item_similarities.filter(item_similarities["idA"]!=item_similarities["idB"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
item_similarities.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------+------------------+
# idA|   idB| EuclideanDistance|
# +---+------+------------------+
# 220|  4929|1.0674378409097194|
#  10|  1340|1.3482610776383614|
#  10|  3200|1.5806104158124294|
#  10|120130|1.2666859905453882|
#  10|  3551|1.2246038527900558|
# +---+------+------------------+
# only showing top 5 rows
#
# </div>

# %%
item_similarities.registerTempTable("item_similarities")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Find the similar moives for moive with id: 463

# %%
# %sql
with temp as (select idA, idB,  EuclideanDistance as sim 
from item_similarities 
where idA = 463
order by 3 desc
limit 5)

select movieId, title from movies_df
where movieId in (select idB from temp)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Movie with id = 463 hasn't been rated.

# %%
# %sql
select * from movies_df where movieId = 463
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th><th>genres</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# We have no information about movie 463.

# %% [markdown]
# ### Find the similar moives for moive with id: 471

# %%
# %sql
with temp as (select idA, idB,  EuclideanDistance as sim 
from item_similarities 
where idA = 471
order by 3 desc
limit 5)

select movieId, title from movies_df
where movieId in (select idB from temp)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th></tr></thead><tbody><tr><td>3566</td><td>Big Kahuna, The (2000)</td></tr><tr><td>4477</td><td>Big Top Pee-Wee (1988)</td></tr><tr><td>27251</td><td>10th Kingdom, The (2000)</td></tr><tr><td>39446</td><td>Saw II (2005)</td></tr><tr><td>70994</td><td>Halloween II (2009)</td></tr></tbody></table></div>
